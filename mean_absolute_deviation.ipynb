# %% [markdown]
# The mean absolute deviation of a dataset is the average distance between each data point and the mean. it gives us an idea about the variability in a dataset

# %% [markdown]
# ![image.png](attachment:39315f13-3725-4a00-8f9e-f78af7f8fd0e.png)

# %%
from cProfile import label

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from mean import mean

# %%
sec_A = np.array([75,65,73,68,72,76])
sec_B = np.array([90,47,43,96,93,51])
no = np.array([1,2,3,4,5,6])

# %%
mean = np.mean(sec_A)

# %%
mean_sec_b = np.mean(sec_B)

# %%
mean_sec_b
# Out:
# np.float64(70.0)

# %%
plt.figure(figsize=(10,3))
plt.scatter(sec_A,no ,label = 'sec-A')
plt.scatter(sec_B,no,color='red',label='sec-B')
plt.plot([70,70,70,70,70,70],no,color='blue',label='mean')
plt.legend()
plt.show()

# %% [markdown]
# this is modulas

# %%
np.abs(-2)
# Out:
# np.int64(2)

# %%
sec_A - mean
# Out:
# array([ 3.5, -6.5,  1.5, -3.5,  0.5,  4.5])

# %%
np.abs(sec_A - mean)
# Out:
# array([3.5, 6.5, 1.5, 3.5, 0.5, 4.5])

# %%
sum(np.abs(sec_A - mean))
# Out:
# np.float64(20.0)

# %%
mad_a = sum(np.abs(sec_A - mean))/len(sec_A)
mad_b = sum(np.abs(sec_B - mean_sec_b))/len(sec_B)

# %%
mad_a,mad_b
# Out:
# (np.float64(3.3333333333333335), np.float64(23.0))

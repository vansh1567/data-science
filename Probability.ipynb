# %% [markdown]
# Random Variables

# %% [markdown]
# ![image.png](attachment:9adeac91-e23e-4094-96e4-e9d24b017287.png)

# %% [markdown]
# 1. Discrete Random Variable:- A random variable that takes on a countable number of distint value or fixed range of value
# 2. Continuous Random Variable:- A random variable that can take any value within the range it can decimal value and they are basically uncountable

# %% [markdown]
# ![image.png](attachment:b071aad7-06db-4d87-aa03-e224fa16f70b.png)

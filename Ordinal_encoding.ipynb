# %% [markdown]
# ![image.png](attachment:9fd54dd8-5d7f-448f-918f-7f4b486c6ae1.png)

# %% [markdown]
# Cyclic Method

# %%
import pandas as pd

# %%
df = pd.DataFrame({"size":["s","m","l","xl","s","m","l","s","s","l","xl","m"]})

# %%
df
# Out:
#    size
# 0     s
# 1     m
# 2     l
# 3    xl
# 4     s
# 5     m
# 6     l
# 7     s
# 8     s
# 9     l
# 10   xl
# 11    m

# %%
ord_data = [["s","m","l","xl"]]

# %%
from sklearn.preprocessing import OrdinalEncoder
oe = OrdinalEncoder(categories=ord_data)
oe.fit(df[['size']])
# Out:
# OrdinalEncoder(categories=[['s', 'm', 'l', 'xl']])

# %%
df["size_en"] = oe.transform(df[['size']])

# %%
df
# Out:
#    size  size_en
# 0     s      0.0
# 1     m      1.0
# 2     l      2.0
# 3    xl      3.0
# 4     s      0.0
# 5     m      1.0
# 6     l      2.0
# 7     s      0.0
# 8     s      0.0
# 9     l      2.0
# 10   xl      3.0
# 11    m      1.0

# %% [markdown]
# Map Function

# %%
ord_data1 = {"s":0,"m":1,"l":2,"xl":3}

# %%
df["size_en_map"] = df["size"].map(ord_data1)

# %%
df
# Out:
#    size  size_en  size_en_map
# 0     s      0.0            0
# 1     m      1.0            1
# 2     l      2.0            2
# 3    xl      3.0            3
# 4     s      0.0            0
# 5     m      1.0            1
# 6     l      2.0            2
# 7     s      0.0            0
# 8     s      0.0            0
# 9     l      2.0            2
# 10   xl      3.0            3
# 11    m      1.0            1

# %%
df3 = pd.read_csv("data/loan.csv")

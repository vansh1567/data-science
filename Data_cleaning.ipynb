# %% [markdown]
# data cleaning is the process of preparing data for analysis /ml/dl by removing or modifying data that is incorrect, incomplete, irrelevant, duplicated or improperly formatted

# %% [markdown]
# ![image.png](attachment:c9cfb1a2-2e57-49fb-9fe0-580b45b2949e.png)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data/loan.csv")

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df.shape
# Out:
# (614, 13)

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(149)

# %% [markdown]
# we cant understand better according to patterns so we use percentage value

# %%
df.shape[0]
# Out:
# 614

# %%
(df.isnull().sum()/df.shape[0])*100
# Out:
# Loan_ID              0.000000
# Gender               2.117264
# Married              0.488599
# Dependents           2.442997
# Education            0.000000
# Self_Employed        5.211726
# ApplicantIncome      0.000000
# CoapplicantIncome    0.000000
# LoanAmount           3.583062
# Loan_Amount_Term     2.280130
# Credit_History       8.143322
# Property_Area        0.000000
# Loan_Status          0.000000
# dtype: float64

# %% [markdown]
# it is showing how many percent of null values are there in every coloumn

# %%
(df.isnull().sum().sum()/(df.shape[0]*df.shape[1]))*100
# Out:
# np.float64(1.8667000751691305)

# %% [markdown]
# it is showing what percentage of null value is presnt in whole DF

# %%
df.notnull().sum()
# Out:
# Loan_ID              614
# Gender               601
# Married              611
# Dependents           599
# Education            614
# Self_Employed        582
# ApplicantIncome      614
# CoapplicantIncome    614
# LoanAmount           592
# Loan_Amount_Term     600
# Credit_History       564
# Property_Area        614
# Loan_Status          614
# dtype: int64

# %%
df.notnull().sum().sum()
# Out:
# np.int64(7833)

# %% [markdown]
# it is showing total filled data

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# this graph is showing the null values through the graph

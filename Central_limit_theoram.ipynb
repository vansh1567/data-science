# %% [markdown]
# ![image.png](attachment:b2fb9a65-a4fd-4105-8ee7-76e3560be4b3.png)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pop_data = [np.random.randint(10, 100) for i in range(10000)]

# %%
pop_data
# Out:
# [45,
#  39,
#  72,
#  67,
#  57,
#  72,
#  24,
#  27,
#  55,
#  38,
#  10,
#  77,
#  13,
#  92,
#  17,
#  82,
#  26,
#  32,
#  47,
#  96,
#  88,
#  95,
#  85,
#  20,
#  77,
#  14,
#  99,
#  32,
#  11,
#  91,
#  90,
#  64,
#  59,
#  59,
#  51,
#  51,
#  56,
#  32,
#  37,
#  33,
#  20,
#  73,
#  72,
#  18,
#  77,
#  65,
#  13,
#  34,
#  50,
#  25,
#  23,
#  83,
#  20,
#  23,
#  53,
#  42,
#  36,
#  82,
#  32,
#  85,
#  10,
#  67,
#  23,
#  38,
#  79,
#  69,
#  16,
#  91,
#  84,
#  41,
#  10,
#  12,
#  70,
#  55,
#  92,
#  60,
#  90,
#  22,
#  21,
#  45,
#  19,
#  12,
#  61,
#  78,
#  24,
#  91,
#  77,
#  34,
#  51,
#  53,
#  95,
#  39,
#  19,
#  96,
#  36,
#  65,
#  89,
#  50,
#  45,
#  99,
#  97,
#  69,
#  20,
#  64,
#  94,
#  82,
#  26,
#  86,
#  74,
#  11,
#  96,
#  12,
#  48,
#  70,
#  98,
#  79,
#  47,
#  93,
#  91,
#  23,
#  22,
#  85,
#  25,
#  19,
#  98,
#  56,
#  24,
#  18,
#  99,
#  34,
#  88,
#  53,
#  18,
#  81,
#  31,
#  22,
#  88,
#  74,
#  39,
#  93,
#  32,
#  87,
# ...

# %%
np.mean(pop_data)
# Out:
# np.float64(54.8892)

# %%
pop_table = pd.DataFrame({"pop_data": pop_data})

# %%
pop_table
# Out:
#       pop_data
# 0           45
# 1           39
# 2           72
# 3           67
# 4           57
# ...        ...
# 9995        77
# 9996        73
# 9997        98
# 9998        70
# 9999        36
#
# [10000 rows x 1 columns]

# %%
pop_table.dtypes
# Out:
# pop_data    int64
# dtype: object

# %%
plt.figure(figsize=(8, 4))
sns.kdeplot(x="pop_data", data=pop_table)
plt.show()

# %% [markdown]
# we will pick 10percent of data

# %%
(10000*10)/100
# Out:
# 1000.0

# %% [markdown]
# we have to pick lesser than 1000 data

# %%
np.random.choice(pop_data)
# Out:
# np.int64(34)

# %%
sample_mean =[]
for i in range(60):
    sample_data =[]
    for data in range(500):
        sample_data.append(np.random.choice(pop_data))
    sample_mean.append(np.mean(sample_data))

# %%
np.mean(sample_mean)
# Out:
# np.float64(54.81233333333333)

# %%
sample_M = pd.DataFrame({"sample_mean": sample_mean})

# %%
sns.kdeplot(x="sample_mean", data=sample_M)
plt.show()

# %% [markdown]
# As we can see the the mean of small sample datas and whole population data is almost same

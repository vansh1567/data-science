# %% [markdown]
# Machine learning is the science of getting computer to learn and act like human do by feeding them data and information in form of observation and real world interaction

# %% [markdown]
# ![image.png](attachment:5e8c8eb7-31f4-4556-8fe3-a0b2fa45c049.png)

# %% [markdown]
# we feed old data to ML algo then it trains on the data than i build a logical model when we feed it new data it gives us the output

# %% [markdown]
# ![image.png](attachment:b8001c83-7666-4b12-9f13-e50167288def.png)

# %% [markdown]
# in traditional programming we we create a program then gives the input then it generates the output
#
# but in ML we gives input and output both and it generates the program by itself

# %% [markdown]
# Types of ML
# 1. Supervised learning
# 2. Unsupervised learning
# 3. Reinforcement learning

# %% [markdown]
# Supervised learning
#
# it used when i have to predict anything for future or like we have to create a recommended system

# %% [markdown]
# Unsupervised learning
#
# it is used have we have to do classification or creating different groups of diffrent items

# %% [markdown]
# Reinforcement learning
#
# Reinforcement Learning (RL) is a type of Machine Learning where an agent learns by interacting with an environment and receiving rewards or penalties for its actions.

# %% [markdown]
# ![image.png](attachment:217ff5b6-fc67-4198-9967-0912b40cbdd2.png)

# %% [markdown]
# ![image.png](attachment:3a323fac-f77e-4cdd-be91-75ebb96a2f90.png)

# %% [markdown]
# ![image.png](attachment:a7b2aed0-df7c-4af2-881c-bd0547dddfac.png)

# %% [markdown]
# ![image.png](attachment:e879af4d-4351-4017-85ff-501dad67da61.png)

# %% [markdown]
# ![image.png](attachment:8660bbfa-7f78-41e6-9da6-2f4fcbec7d6f.png)

# %% [markdown]
# ![image.png](attachment:4d1796ce-f15a-4c31-a520-9d4adf4f872b.png)

# %% [markdown]
# ![image.png](attachment:62f01752-bd49-4a66-847f-fcb2845c756e.png)

# %% [markdown]
# Discrete
#
# only perfect numbers are allowed and number can be repeat
#
# Continuous
#
# between any range of number and it can be consider decimal numbers too in between

# %% [markdown]
# ![image.png](attachment:07e4bbbc-4020-4085-93a5-13fd811d142d.png)

# %% [markdown]
# Ordinal
#
# data will be arranged in the order
#
# Nominal
#
# is not neccasary to arrange in order

# %% [markdown]
# Date time and mixed variable

# %% [markdown]
# date time
#
# date time can contain date only and time only
#
# Mixed
#
# can contain number and categories data

# %% [markdown]
# Numerical data can be in
# int
# float
#
# Categorical will be in
# object
#
# mixed will be
# object
